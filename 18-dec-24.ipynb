# %%
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
# automobile dataset
# mpg = sns.load_dataset('mpg')
lst = sns.get_dataset_names()
lst
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
mpg.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 mpg.head()
#
# NameError: name 'mpg' is not defined

# %%
# automobile dataset
mpg = sns.load_dataset('mpg')
# to see all dataset
# lst = sns.get_dataset_names()
# lst

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
#distrubution plot
tpl = tuple(mpg['cylinders'])
sns.displot(tpl, bins=6)

# %%
#distrubution plot
tpl = tuple(mpg['cylinders'])
sns.displot(tpl, bins=range(3, 10, 1), kde=False)

# %%
#distrubution plot
tpl = tuple(mpg['cylinders'])
sns.displot(tpl, bins=range(3, 10, 1), kde=True)

# %%
mpg['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
# countplot
sns.countplot(x='cylinders', data=mpg, color='blue', hue='origin')
# Out:
# C:\Users\telmo\AppData\Local\Temp\ipykernel_17224\225282378.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.countplot(x='cylinders', data=mpg, color='blue', hue='origin')
# <Axes: xlabel='cylinders', ylabel='count'>

# %%
# countplot
sns.countplot(x='cylinders', data=mpg, color='blue', hue='origin')
plt.legend(loc='lower right')
# Out:
# C:\Users\telmo\AppData\Local\Temp\ipykernel_17224\926238214.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.countplot(x='cylinders', data=mpg, color='blue', hue='origin')

# %%
#boxplot
sns.boxplot(x='origin',y='acceleration',data=mpg)
# Out:
# <Axes: xlabel='origin', ylabel='acceleration'>

# %%
# joint plot
sns.jointplot(x='horsepower', y='acceleration', data=mpg)

# %%
# scatter plot 
sns.scatterplot(x='horsepower', y='acceleration',data=mpg)
# Out:
# <Axes: xlabel='horsepower', ylabel='acceleration'>

# %%
# scatter plot 
sns.scatterplot(x='horsepower', y='acceleration',data=mpg, alpha=0.8)
# Out:
# <Axes: xlabel='horsepower', ylabel='acceleration'>

# %%
# scatter plot 
sns.scatterplot(x='horsepower', y='acceleration',data=mpg, alpha=0.1)
# Out:
# <Axes: xlabel='horsepower', ylabel='acceleration'>

# %%
# scatter plot 
sns.scatterplot(x='horsepower', y='acceleration',data=mpg, alpha=0.3)
# Out:
# <Axes: xlabel='horsepower', ylabel='acceleration'>

# %%
# scatter plot 
sns.scatterplot(x='horsepower', y='acceleration',data=mpg,hue='origin')
# Out:
# <Axes: xlabel='horsepower', ylabel='acceleration'>

# %%
# sub plots in 2x2 grid
plt.figure(figsize= (10, 10))
plt.subplot(2,2,1)
sns.scatterplot(x='horsepower', y='acceleration', hue='origin', data=mpg)

plt.subplot(2,2,2)
sns.scatterplot(x='horsepower', y='acceleration', alpha=0.2, data=mpg)

plt.subplot(2,2,3)
sns.boxplot(x='oringin',y='acceleration',data=mpg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 10
#       7 sns.scatterplot(x='horsepower', y='acceleration', alpha=0.2, data=mpg)
#       9 plt.subplot(2,2,3)
# ---> 10 sns.boxplot(x='oringin',y='acceleration',data=mpg)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
# ...

# %%
# sub plots in 2x2 grid
plt.figure(figsize= (10, 10))
plt.subplot(2,2,1)
sns.scatterplot(x='horsepower', y='acceleration', hue='origin', data=mpg)

plt.subplot(2,2,2)
sns.scatterplot(x='horsepower', y='acceleration', alpha=0.2, data=mpg)

plt.subplot(2,2,3)
sns.boxplot(x='origin', y='acceleration', data=mpg)

plt.savefig('my_plot.png)
# Out:
#   Cell In[69], line 12
#     plt.savefig('my_plot.png)
#                 ^
# SyntaxError: unterminated string literal (detected at line 12)

# %%
# lmplot
sns.lmplot(x='horsepower', y='acceleration', data=mpg, hue='origin')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
len(iris)
# Out:
# 150

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# pair plot
sns.pairplot(iris)

# %%
# pair plot
sns.pairplot(iris, hue='species')

# %%
# pair plot
sns.pairplot(iris, hue='species', palette='BrBG')

# %%
# pair plot
sns.pairplot(iris, hue='species', palette='coolwarm')

# %%
# pair plot
sns.pairplot(iris, hue='species', palette='coolwarm', markers= ['o', 'd', 's'])

# %%
# pair plot
sns.pairplot(iris, vars = ['sepal_lenth', 'sepal width'], hue='species')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal_lenth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 2
#       1 # pair plot
# ...

# %%
# heat map
df = iris.iloc[:10, 0:4]
sns.heatmap(df)
# Out:
# <Axes: >

# %%
# heat map
df = iris.iloc[:10, 0:4]
sns.heatmap(df,annot=True)
# Out:
# <Axes: >

# %%
# cat plot 
sns.catplot(x='species',y='sepal_length',data=iris)

# %%
# cat plot 
sns.catplot(x='species',y='sepal_length',data=iris,kind='violin')

# %%
# retrieving data from an xml file
import xml.etree.ElementTree as ET
tree = ET.parse('d:/py/cust-data.xml')

# %%
root = tree.getroot()
print('Root tag name=', root.tag)

# %%
for child in root:
    print('child tag name=', child.tag

# %%
# retrieve info from child tags
for c in root.findall('customer'):
    a = c.attrib
    print(a)

# %%
# retrieve info from child tags
for c in root.findall('customer'):
    a = c.attrib
    print(a)

    t = a.get('type')
    print(t)

    other = c.find('place').text
    print('place=', other)

    other = c.find('amount').text
    print('Amount Rs.', other1)
